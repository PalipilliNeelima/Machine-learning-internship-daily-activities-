# %% [markdown]
# # import pandas

# %%
import pandas as pd
import numpy as np
pd.__version__  # gives the version of pandas
# Out:
# '2.0.3'

# %% [markdown]
# # pandas data structues

# %%
# Series----one-dimesional coulumn
# DataFrames--- table with rows+cloumns

# %%
s=pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df=pd.DataFrame({
    "name":["ishu","kallu","aki"],
    "age":[20,23,25]
})
df
# Out:
#     name  age
# 0   ishu   20
# 1  kallu   23
# 2    aki   25

# %% [markdown]
# # reading data(csv)

# %%
df=pd.read_csv("data.csv")
df
# Out:
#       name  age   city
# 0  neelima   12    kkd
# 1  laskhmi   35  vizag
# 2   akhila   20    ppt
# 3  kalyani   19    kkd
# 4     ishu   20    kkd

# %% [markdown]
# # writing the data into files

# %%
df.to_csv("data.csv",index=False)

# %% [markdown]
# # exploring data

# %%
df.head()
# Out:
#       name  age   city
# 0  neelima   12    kkd
# 1  laskhmi   35  vizag
# 2   akhila   20    ppt
# 3  kalyani   19    kkd
# 4     ishu   20    kkd

# %%
df.tail()
# Out:
#       name  age   city
# 0  neelima   12    kkd
# 1  laskhmi   35  vizag
# 2   akhila   20    ppt
# 3  kalyani   19    kkd
# 4     ishu   20    kkd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   city    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df["name"][df["city"]=="kkd"]
# Out:
# 0    neelima
# 3    kalyani
# 4       ishu
# Name: name, dtype: object

# %%
df[1:3]
# Out:
#       name  age   city
# 1  laskhmi   35  vizag
# 2   akhila   20    ppt

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.dtypes
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
# df.Date-- to display the date it can be also accessed as    --------- df['Date'] -------------

# %%
df[['city','age']]
# Out:
#     city  age
# 0    kkd   12
# 1  vizag   35
# 2    ppt   20
# 3    kkd   19
# 4    kkd   20

# %% [markdown]
# # Missing values

# %%
df.isnull()
# Out:
#     name    age   city
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False

# %%
df.isnull().sum() # total missin values
# Out:
# name    0
# age     0
# city    0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]   # show rows with missing values
# Out:
# Empty DataFrame
# Columns: [name, age, city]
# Index: []

# %%
#df['age']=df['age'].fillna(df['age'].mean()) or df['age']=df['age'].fillna(df['age'].some value)   to fill null value
