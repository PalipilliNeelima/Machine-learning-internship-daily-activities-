# %%
#file handling
f=open('neelima.txt','w')
print("file name:",f.name)
print("file mode:",f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# file name: neelima.txt
# file mode: w
# False
# True
# False
# True

# %%
with open("neelima.txt","r") as file:
    content=file.read()
print(content)
# Out:
# my name is neelima palipilli. i'm from kkd.

# %%
with open("neelima.txt","r") as file:
    content=file.readline()
print(content)
# Out:
# my name is neelima palipilli. i'm from kkd.

# %%
with open("neelima.txt","r") as file:
    content=file.readlines()
print(content)
# Out:
# ["my name is neelima palipilli. i'm from kkd.\n", 'gud morning.']

# %%
with open("neelima.txt","w") as file:
    
    file.write("hello everyone")

# %%
l=["hi guys\n", "welcome\n"]
with open("neelima.txt","w")as file:
    file.writelines(l)

# %%
with open("neelima.txt","a") as file:
    file.write("gud morning")

# %%
#csv file
import csv
with open("data.csv","w",newline="")as file:
    writer=csv.writer(file)
    writer.writerow(["name","age","city"])
    writer.writerow(["neelima","12","kkd"])
    writer.writerow(["laskhmi","35","vizag"])

# %%
import csv
with open("data.csv","r")as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'city']
# ['neelima', '12', 'kkd']
# ['laskhmi', '35', 'vizag']
